# %%
import pandas as pd

# %%
green_data=pd.read_parquet('green_tripdata_2025-11.parquet')
green_data.head(10)
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2025-11-01 00:34:48   2025-11-01 00:41:39                  N
# 1         2  2025-11-01 00:18:52   2025-11-01 00:24:27                  N
# 2         2  2025-11-01 01:03:14   2025-11-01 01:15:24                  N
# 3         2  2025-11-01 00:10:57   2025-11-01 00:24:53                  N
# 4         1  2025-11-01 00:03:48   2025-11-01 00:19:38                  N
# 5         1  2025-11-01 00:42:13   2025-11-01 01:04:50                  N
# 6         2  2025-11-01 00:05:41   2025-11-01 00:39:20                  N
# 7         2  2025-11-01 00:42:14   2025-11-01 01:13:20                  N
# 8         2  2025-11-01 00:03:08   2025-11-01 00:06:27                  N
# 9         2  2025-11-01 00:56:33   2025-11-01 01:01:34                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            74            42              1.0           0.74
# ...

# %%
green_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46912 entries, 0 to 46911
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               46912 non-null  int32
#  1   lpep_pickup_datetime   46912 non-null  datetime64[us]
#  2   lpep_dropoff_datetime  46912 non-null  datetime64[us]
#  3   store_and_fwd_flag     41343 non-null  object
#  4   RatecodeID             41343 non-null  float64
#  5   PULocationID           46912 non-null  int32
#  6   DOLocationID           46912 non-null  int32
#  7   passenger_count        41343 non-null  float64
#  8   trip_distance          46912 non-null  float64
#  9   fare_amount            46912 non-null  float64
#  10  extra                  46912 non-null  float64
#  11  mta_tax                46912 non-null  float64
#  12  tip_amount             46912 non-null  float64
#  13  tolls_amount           46912 non-null  float64
# ...

# %% [markdown]
# - Most Dtypes appear to be correct - Payment type and trip type may be objects instead of floats. Need to check original data. Passenger count likely should be int.
#
# - Some null values in store_and_fwd_flag, RatecodeID, passenger_count, payment_type, trip_type, congestion_surcharge
#
# - ehail_fee has no non-null values - should be removed

# %%
green_data = green_data.dropna(axis=1, how='all')

dtype = {
    "VendorID": "Int64",
    "lpep_pickup_datetime": "datetime64[ns]",
    "lpep_dropoff_datetime": "datetime64[ns]",
    "passenger_count": "Int64",
    "trip_distance": "float64",
    "RatecodeID": "Int64",
    "store_and_fwd_flag": "string",
    "PULocationID": "Int64",
    "DOLocationID": "Int64",
    "payment_type": "Int64",
    "fare_amount": "float64",
    "extra": "float64",
    "mta_tax": "float64",
    "tip_amount": "float64",
    "tolls_amount": "float64",
    "improvement_surcharge": "float64",
    "total_amount": "float64",
    "trip_type": "Int64",
    "congestion_surcharge": "float64",
    "cbd_congestion_fee": "float64"
}
green_data = green_data.astype(dtype)
green_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46912 entries, 0 to 46911
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               46912 non-null  Int64
#  1   lpep_pickup_datetime   46912 non-null  datetime64[ns]
#  2   lpep_dropoff_datetime  46912 non-null  datetime64[ns]
#  3   store_and_fwd_flag     41343 non-null  string
#  4   RatecodeID             41343 non-null  Int64
#  5   PULocationID           46912 non-null  Int64
#  6   DOLocationID           46912 non-null  Int64
#  7   passenger_count        41343 non-null  Int64
#  8   trip_distance          46912 non-null  float64
#  9   fare_amount            46912 non-null  float64
#  10  extra                  46912 non-null  float64
#  11  mta_tax                46912 non-null  float64
#  12  tip_amount             46912 non-null  float64
#  13  tolls_amount           46912 non-null  float64
# ...

# %%
taxi_zone=pd.read_csv('taxi_zone_lookup.csv')
#taxi_zone.head(10)
taxi_zone.tail(15)
# Out:
#      LocationID        Borough                       Zone service_zone
# 250         251  Staten Island                Westerleigh    Boro Zone
# 251         252         Queens                 Whitestone    Boro Zone
# 252         253         Queens              Willets Point    Boro Zone
# 253         254          Bronx   Williamsbridge/Olinville    Boro Zone
# 254         255       Brooklyn  Williamsburg (North Side)    Boro Zone
# 255         256       Brooklyn  Williamsburg (South Side)    Boro Zone
# 256         257       Brooklyn            Windsor Terrace    Boro Zone
# 257         258         Queens                  Woodhaven    Boro Zone
# 258         259          Bronx         Woodlawn/Wakefield    Boro Zone
# 259         260         Queens                   Woodside    Boro Zone
# 260         261      Manhattan         World Trade Center  Yellow Zone
# 261         262      Manhattan             Yorkville East  Yellow Zone
# ...

# %%
taxi_zone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   LocationID    265 non-null    int64
#  1   Borough       265 non-null    object
#  2   Zone          264 non-null    object
#  3   service_zone  263 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 8.4+ KB

# %% [markdown]
# - Need to research what LocationID refers to. Appears to be row number. Does it match pick up and drop off location ids in green table?
#
# - Service zone is missing two values and zone is missing one value.
#
# - There are locations with the string 'Unknown'. More missing data than it appears?
